# %% [markdown]
# ## Hello World

# %%
from src.Wordle import Wordle
import pandas as pd
import matplotlib.pyplot as plt

# %%
exclude_previous_answers = True
future_wordle_list = Wordle()._find_allowed_answers()
guess_count_excluded = [Wordle().test_search(word) for word in future_wordle_list]
word_counts_excluded = pd.Series(guess_count_excluded)
hist_excluded = word_counts_excluded.value_counts()
# Out:
# Found the word: abbot
# Found the word: abhor
# Found the word: abide
# Found the word: abled
# Found the word: abode
# Found the word: abort
# Found the word: abuse
# Found the word: acorn
# Found the word: adage
# Found the word: adept
# Found the word: admin
# Found the word: adorn
# Found the word: affix
# Found the word: afire
# Found the word: afoot
# Found the word: afoul
# Found the word: after
# Found the word: agora
# Found the word: aider
# Found the word: aisle
# Found the word: alarm
# Found the word: alert
# Found the word: algae
# Found the word: alibi
# Found the word: align
# Found the word: alive
# Found the word: allay
# Found the word: alley
# Found the word: allot
# Found the word: alloy
# Found the word: along
# Found the word: amass
# Found the word: amaze
# Found the word: amble
# Found the word: amend
# Found the word: amity
# Found the word: among
# Found the word: amply
# Found the word: amuse
# Found the word: angle
# Found the word: angst
# ...

# %%
plt.bar(hist_excluded.index, hist_excluded.values)
plt.show()
